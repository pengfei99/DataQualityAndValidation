# %%
from ruamel.yaml import YAML
import great_expectations as ge
from pprint import pprint

yaml = YAML()
context = ge.get_context()

# %%
my_checkpoint_name = "census_income_checkpoint"
auto_check="profiler_generated_cp"
context.run_checkpoint(checkpoint_name=auto_check)
context.open_data_docs()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/.cache/pypoetry/virtualenvs/dataqualityandvalidation-6LYnP9NJ-py3.8/lib/python3.8/site-packages/great_expectations/data_context/store/tuple_store_backend.py:303, in TupleFilesystemStoreBackend._get(self, key)
#     302 try:
# --> 303     with open(filepath) as infile:
#     304         contents: str = infile.read().rstrip("\n")
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/pliu/git/DataQualityAndValidation/02.great_expectations_validation/great_expectations/checkpoints/profiler_generated_cp.yml'
#
# During handling of the above exception, another exception occurred:
#
# InvalidKeyError                           Traceback (most recent call last)
# File ~/.cache/pypoetry/virtualenvs/dataqualityandvalidation-6LYnP9NJ-py3.8/lib/python3.8/site-packages/great_expectations/checkpoint/toolkit.py:165, in get_checkpoint(data_context, checkpoint_store, name, ge_cloud_id)
#     164 try:
# --> 165     checkpoint_config: CheckpointConfig = checkpoint_store.get(key=key)
#     166 except ge_exceptions.InvalidKeyError as exc_ik:
#
# File ~/.cache/pypoetry/virtualenvs/dataqualityandvalidation-6LYnP9NJ-py3.8/lib/python3.8/site-packages/great_expectations/data_context/store/store.py:150, in Store.get(self, key)
#     149     self._validate_key(key)
# --> 150     value = self._store_backend.get(self.key_to_tuple(key))
#     152 if value:
#
# File ~/.cache/pypoetry/virtualenvs/dataqualityandvalidation-6LYnP9NJ-py3.8/lib/python3.8/site-packages/great_expectations/data_context/store/store_backend.py:121, in StoreBackend.get(self, key, **kwargs)
#     120 self._validate_key(key)
# --> 121 value = self._get(key, **kwargs)
#     122 return value
#
# File ~/.cache/pypoetry/virtualenvs/dataqualityandvalidation-6LYnP9NJ-py3.8/lib/python3.8/site-packages/great_expectations/data_context/store/tuple_store_backend.py:306, in TupleFilesystemStoreBackend._get(self, key)
#     305 except FileNotFoundError:
# --> 306     raise InvalidKeyError(
#     307         f"Unable to retrieve object from TupleFilesystemStoreBackend with the following Key: {str(filepath)}"
#     308     )
#     310 return contents
#
# InvalidKeyError: Unable to retrieve object from TupleFilesystemStoreBackend with the following Key: /home/pliu/git/DataQualityAndValidation/02.great_expectations_validation/great_expectations/checkpoints/profiler_generated_cp.yml
#
# During handling of the above exception, another exception occurred:
#
# CheckpointNotFoundError                   Traceback (most recent call last)
# Input In [2], in <module>
#       1 my_checkpoint_name = "census_income_checkpoint"
#       2 auto_check="profiler_generated_cp"
# ----> 3 context.run_checkpoint(checkpoint_name=auto_check)
#       4 context.open_data_docs()
#
# File ~/.cache/pypoetry/virtualenvs/dataqualityandvalidation-6LYnP9NJ-py3.8/lib/python3.8/site-packages/great_expectations/core/usage_statistics/usage_statistics.py:307, in usage_statistics_enabled_method.<locals>.usage_statistics_wrapped_method(*args, **kwargs)
#     304     if args_payload_fn is not None:
#     305         nested_update(event_payload, args_payload_fn(*args, **kwargs))
# --> 307     result = func(*args, **kwargs)
#     308     message["success"] = True
#     309 except Exception:
#
# File ~/.cache/pypoetry/virtualenvs/dataqualityandvalidation-6LYnP9NJ-py3.8/lib/python3.8/site-packages/great_expectations/data_context/data_context.py:3179, in BaseDataContext.run_checkpoint(self, checkpoint_name, template_name, run_name_template, expectation_suite_name, batch_request, action_list, evaluation_parameters, runtime_configuration, validations, profilers, run_id, run_name, run_time, result_format, ge_cloud_id, expectation_suite_ge_cloud_id, **kwargs)
#    3132 @usage_statistics_enabled_method(
#    3133     event_name="data_context.run_checkpoint",
#    3134 )
#    (...)
#    3153     **kwargs,
#    3154 ) -> CheckpointResult:
#    3155     """
#    3156     Validate against a pre-defined Checkpoint. (Experimental)
#    3157     Args:
#    (...)
#    3177         CheckpointResult
#    3178     """
# -> 3179     return checkpoint_toolkit.run_checkpoint(
#    3180         data_context=self,
#    3181         checkpoint_store=self.checkpoint_store,
#    3182         ge_cloud_mode=self.ge_cloud_mode,
#    3183         checkpoint_name=checkpoint_name,
#    3184         template_name=template_name,
#    3185         run_name_template=run_name_template,
#    3186         expectation_suite_name=expectation_suite_name,
#    3187         batch_request=batch_request,
#    3188         action_list=action_list,
#    3189         evaluation_parameters=evaluation_parameters,
#    3190         runtime_configuration=runtime_configuration,
#    3191         validations=validations,
#    3192         profilers=profilers,
#    3193         run_id=run_id,
#    3194         run_name=run_name,
#    3195         run_time=run_time,
#    3196         result_format=result_format,
#    3197         ge_cloud_id=ge_cloud_id,
#    3198         expectation_suite_ge_cloud_id=expectation_suite_ge_cloud_id,
#    3199         **kwargs,
#    3200     )
#
# File ~/.cache/pypoetry/virtualenvs/dataqualityandvalidation-6LYnP9NJ-py3.8/lib/python3.8/site-packages/great_expectations/checkpoint/toolkit.py:290, in run_checkpoint(data_context, checkpoint_store, ge_cloud_mode, checkpoint_name, template_name, run_name_template, expectation_suite_name, batch_request, action_list, evaluation_parameters, runtime_configuration, validations, profilers, run_id, run_name, run_time, result_format, ge_cloud_id, expectation_suite_ge_cloud_id, **kwargs)
#     288 # TODO mark experimental
#     289 batch_request, validations = get_batch_request_dict(batch_request, validations)
# --> 290 checkpoint: Union[Checkpoint, SimpleCheckpoint, LegacyCheckpoint] = get_checkpoint(
#     291     data_context=data_context,
#     292     checkpoint_store=checkpoint_store,
#     293     name=checkpoint_name,
#     294     ge_cloud_id=ge_cloud_id,
#     295 )
#     296 checkpoint_config_from_store: dict = checkpoint.config.to_json_dict()
#     298 if (
#     299     "runtime_configuration" in checkpoint_config_from_store
#     300     and "result_format" in checkpoint_config_from_store["runtime_configuration"]
#     301 ):
#
# File ~/.cache/pypoetry/virtualenvs/dataqualityandvalidation-6LYnP9NJ-py3.8/lib/python3.8/site-packages/great_expectations/checkpoint/toolkit.py:167, in get_checkpoint(data_context, checkpoint_store, name, ge_cloud_id)
#     165     checkpoint_config: CheckpointConfig = checkpoint_store.get(key=key)
#     166 except ge_exceptions.InvalidKeyError as exc_ik:
# --> 167     raise ge_exceptions.CheckpointNotFoundError(
#     168         message=f'Non-existent Checkpoint configuration named "{key.configuration_key}".\n\nDetails: {exc_ik}'
#     169     )
#     170 except ValidationError as exc_ve:
#     171     raise ge_exceptions.InvalidCheckpointConfigError(
#     172         message="Invalid Checkpoint configuration", validation_error=exc_ve
#     173     )
#
# CheckpointNotFoundError: Non-existent Checkpoint configuration named "profiler_generated_cp".
#
# Details: Unable to retrieve object from TupleFilesystemStoreBackend with the following Key: /home/pliu/git/DataQualityAndValidation/02.great_expectations_validation/great_expectations/checkpoints/profiler_generated_cp.yml
